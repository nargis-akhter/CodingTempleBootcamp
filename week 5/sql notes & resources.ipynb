# %% [markdown]
# ## SQL NOTES

# %% [markdown]
# ![sql cheat sheet.jpeg](<attachment:sql cheat sheet.jpeg>)

# %% [markdown]
# ![sql.jpg](attachment:sql.jpg)

# %% [markdown]
# ![sql2.jpg](attachment:sql2.jpg)

# %% [markdown]
# ![sql3.jpg](attachment:sql3.jpg)

# %% [markdown]
# ## Resources

# %% [markdown]
# https://www.sqlstyle.guide/#overview

# %% [markdown]
# https://www.postgresqltutorial.com/

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html

# %% [markdown]
# https://lucid.co/
