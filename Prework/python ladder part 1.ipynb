# %% [markdown]
# # Python Ladder Challenges - Part 1

# %% [markdown]
# # Climb the Ladder!
# Our class moves quickly! Sometimes, it feels like we make leaps in logic that are a bit too big. Learn Python _slowly_, by doing many, many examples. Problems in this notebook start out easy and progressively get harder, so that the next rung of the Python ladder is always within reach.

# %% [markdown]
# # Section I: Numbers, variables, and math.

# %% [markdown]
# 1) What is 123456789 times 987654321?

# %%
123456789 * 987654321
# Out:
# 121932631112635269

# %% [markdown]
# 2) Create a variable called `mass` that is equal to 100.

# %%
mass = 100

# %% [markdown]
# 3) Create a variable called `velocity` that is equal to 5.

# %%
velocity = 5

# %% [markdown]
# 4) In physics, the momentum an object is exerting is equal to its mass times its velocity. That is, $p = mv$. Use the variables you defined above to compute this object's momentum.

# %%
p = mass * velocity
p
# Out:
# 500

# %% [markdown]
# 5) The kinetic energy of an object is half its mass times the square of its velocity. That is, $K = \frac{1}{2}mv^2$. Compute the kinetic energy for this object using the variables you've already created.

# %%
k = (1/2) * mass * velocity ** 2
k
# Out:
# 1250.0

# %% [markdown]
# ### How much icing do you need?
# In the next few exercises, our goal will be to figure out how much icing we will need to perfectly cover a giant doughnut. The doughnut features a hole (unfortunately no jelly filling), and a few large sprinkles. We only need to find the area of the red region in this shape.
#
# ![](imgs/donut.png)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6) Create a variable called `pi` that is equal to 3.141

# %%
pi = 3.141

# %% [markdown]
# 7) The radius of the largest circle is 13.425. The radius of the smaller circle is 4.792. The sprinkles are right triangles with side length 3.28. Create the variables `R`, `r`, and `s` that represent these values.

# %%
R = 13.425
r = 4.792
s = 3.28

# %% [markdown]
# 8) Find the area of the larger circle (the whole doughnut, including the hole). Call this variable `area_big_circle`.
#
# * _Hint:_ The area of a circle with radius $r$ is $A = \pi r^2$.

# %%
area_big_circle = pi * R ** 2
area_big_circle
# Out:
# 566.1043931250001

# %% [markdown]
# 9) Find the area of the smaller circle (the hole). Call this variable `area_small_circle`.

# %%
area_small_circle = pi * r ** 2
area_small_circle
# Out:
# 72.127612224

# %% [markdown]
# 10) Find the area of one triangle (a sprinkle), where each sprinkle has a base and height of length `s`. Call this variable `area_sprinkle`.
#
# * _Hint:_ The area of a triangle with base $b$ and height $h$ is $A = \frac{1}{2}bh$.

# %%
area_sprinkle = (1/2) * s
area_sprinkle
# Out:
# 1.64

# %% [markdown]
# 11) Using the three values you calculated above, find the area of the shaded region (i.e., how much icing will you need?). Save the result in a variable called `area_donut`.

# %% [markdown]
# # Section II: Strings

# %% [markdown]
# 1) Create a variable called `name` that is equal to your name.

# %%
name = 'Nargis Akhter'

# %% [markdown]
# 2) By adding strings together, introduce yourself in a string. For example `"Hello, my name is Tim!"`. You may use f-strings if you know what they are and prefer to use them.

# %%
print(f"Hello, my name is {name}!")
# Out:
# Hello, my name is Nargis Akhter!

# %% [markdown]
# 3) Define the string `fact` to be `"Python programming is fun."`

# %%
fact = "Python progamming is fun."

# %% [markdown]
# 4) Index `fact` in order to get the "o" in "Python".

# %%
fact[4]
# Out:
# 'o'

# %% [markdown]
# 5) Index `fact` in order to get the "u" in "fun" using a negative index.

# %%
fact[-3]
# Out:
# 'u'

# %% [markdown]
# 6) Slice `fact` in order to get the word "programming".

# %%
fact[7:17]
# Out:
# 'progamming'

# %% [markdown]
# 7) Uppercase `fact`.

# %%
fact.upper()
# Out:
# 'PYTHON PROGAMMING IS FUN.'

# %% [markdown]
# 8) Replace the period at the end of `fact` with an exclamation point.

# %%
fact.replace(".", "!")
# Out:
# 'Python progamming is fun!'

# %% [markdown]
# 9) Use `.split()` to get the second word of this string. Was this easier than one of the problems above?

# %%
fact.split()
# Out:
# ['Python', 'progamming', 'is', 'fun.']

# %% [markdown]
# 10) Reverse `fact`.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-2b5d38a72725> in <cell line: 1>()
# ----> 1 fact.reverse()
#       2
#       3 reverse
#
# AttributeError: 'str' object has no attribute 'reverse'

# %% [markdown]
# 11) Does `fact` contain the letter `y`? To find this answer, use the `in` keyword.

# %%
'y' in fact
# Out:
# True

# %% [markdown]
# 12) How many `o`s does `fact` have?

# %%
# Out:
# True

# %% [markdown]
# 13) Replace all the `o`s in `fact` with an underscore (do not redefine `fact`).

# %%
fact.replace("o", "_")
# Out:
# 'Pyth_n pr_gamming is fun.'

# %% [markdown]
# # Section III: Lists

# %% [markdown]
# 1) Create a list `friends` of your three best friends, `"Alice"`, `"Bob"`, and `"Charlie"`.

# %%
friends = ['Alice', 'Bob', 'Charlie']

# %% [markdown]
# 2) Find the length of `friends`.

# %%
len(friends)
# Out:
# 3

# %% [markdown]
# 3) Add your new friend `"Debbie"` to your list of `friends`.

# %%
friends.append('Debbie')

friends
# Out:
# ['Alice', 'Bob', 'Charlie', 'Debbie', 'Debbie']

# %% [markdown]
# 4) Charlie has no-showed to your piano recital. Remove him from your `friends`.

# %%
friends.remove('Charlie')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-1a6e7ec57839> in <cell line: 1>()
# ----> 1 friends.remove('Charlie')
#
# ValueError: list.remove(x): x not in list

# %%
friends
# Out:
# ['Alice', 'Bob', 'Debbie', 'Debbie']

# %% [markdown]
# 5) Using the `.join()` method, join `friends` to look like this _exactly_: `"Alice & Bob & Debbie"`

# %%
friends.join("", "&")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-c18ca0af3463> in <cell line: 1>()
# ----> 1 friends.join("", "&")
#
# AttributeError: 'list' object has no attribute 'join'

# %% [markdown]
# 6) What is the length of `[]`? What about `[[]]`? Why?

# %%
len[]
# Out:
#   File "<ipython-input-71-d9bad1832c66>", line 1
#     len[]
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# For the next few problems, we'll use this list:

# %%
# Make sure to run this cell!

nested_deep = [1, [2, 3], 4, [5, [6, 7, [8]]]]

# %% [markdown]
# 7) What is the length of `nested_deep`?

# %%
len(nested_deep)
# Out:
# 4

# %% [markdown]
# 8) Index `nested_deep` to get the 5.

# %%
nested_deep[3][0]
# Out:
# 5

# %% [markdown]
# 9) Index `nested_deep` to get the 8.
#
# * _Hint:_ If your answer looks like `[8]`, that's not the correct answer!

# %%
nested_deep[3][1][2][0]
# Out:
# 8
